# %% [markdown]
# <p style="padding-left: 320px; text-align: justify;">&nbsp;</p>
# <p style="padding-left: 240px; text-align: justify;"><span style="font-size: 36pt;"><strong>Introduction to R</strong></span></p>
# <p style="padding-left: 360px; text-align: justify;">&nbsp;</p>
# <p style="padding-left: 360px; text-align: justify;">&nbsp;</p>
# <p style="padding-left: 240px; text-align: justify;"><strong><span style="font-size: 24pt;">Preseted by: Basim Alsaedi, PhD</span></strong></p>
# <p style="padding-left: 240px; text-align: justify;">&nbsp;</p>
# <p style="padding-left: 240px; text-align: justify;"><strong><span style="font-size: 24pt;">&nbsp;&nbsp;&nbsp;&nbsp; Statistics Department</span></strong></p>
# <p style="padding-left: 280px; text-align: justify;"><strong><span style="font-size: 24pt;">&nbsp; University of Tabuk</span></strong></p>
# <p style="text-align: justify; padding-left: 320px;"><img style="width: 200px; display: block; margin-left: auto; margin-right: auto; float: left;" src="Tabuk_UNI_LOGO.jpg" alt="Drawing" /></p>

# %%
%%HTML
<link rel="stylesheet" type="text/css" href="custom.css">
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:1: unexpected SPECIAL
# 1: %%
#     ^
# Traceback:

# %% [markdown]
# <p><span style="font-size: 14pt;">Outlines</span></p>
# <ol>
# <li>Introduction to R</li>
# <li>Creating Dataset</li>
# <li>Data management</li>
# <li>Basic of R graphs</li>
# <li>Handling data.</li>
# </ol>

# %% [markdown]
# <hr style="height:2px;border-width:0;color:black;background-color:black">

# %% [markdown]
# # Introduction To R

# %% [markdown]
# ## Why use R
#
# - R is free!
# - R is a platform.
# - R contains advance statitical "routines" not yet available else where.
# - R has state of the art graphical capabilities.
# - R functionality can be integrated into applications written in other languages.
# - ... and many more to list here.

# %% [markdown]
# ## Why use R
#
# <p class="fragment" data-fragment-index="1">- R is free!</p>
# <p class="fragment" data-fragment-index="2">- R is a platform.</p>
# <p class="fragment" data-fragment-index="3">- R contains advance statitical "routines" not yet available else where.</p>
# <p class="fragment" data-fragment-index="4">- R has state of the art graphical capabilities.</p>
# <p class="fragment" data-fragment-index="5">- R functionality can be integrated into applications written in other languages.</p>
# <p class="fragment" data-fragment-index="6">- ... and many more to list here.</p>

# %% [markdown]
# ## Getting started
# - Visit www.r-project.org
# - Downlaod RStudio www.rstudio.com

# %% [markdown]
# <table><tr>
# <td> <img src="RInterface.png" alt="Drawing" style="width: 400px;"/> </td>
# <td> <img src="RStudioInterface.png" alt="Drawing" style="width: 600px;"/> </td>
# </tr></table>

# %% [markdown]
# <td> <img src="RInterface.png" alt="Drawing" style="width: 400px;"/> </td>

# %% [markdown]
# <td> <img src="RStudioInterface.png" alt="Drawing" style="width: 600px;"/> </td>

# %%
library("car")
scatterplotMatrix(~ income + education + prestige | type, data=Duncan)
# Out:
# plot without title

# %%
scatterplotMatrix(~ income + education + prestige | type, data=Duncan,regLine=FALSE, smooth=list(spread=FALSE))
# Out:
# plot without title

# %%
scatterplotMatrix(~ income + education + prestige,data=Duncan, id=TRUE, smooth=list(method=gamLine))
# Out:
# plot without title

# %%
help("scatterplotMatrix")

# %%
library(help = "base")

# %%
?help

# %%
demo(persp)
# Out:
# 	demo(persp)
# 	---- ~~~~~
#
# > ### Demos for  persp()  plots   -- things not in  example(persp)
# > ### -------------------------
# >
# > require(datasets)
#
# > require(grDevices); require(graphics)
#
# > ## (1) The Obligatory Mathematical surface.
# > ##     Rotated sinc function.
# >
# > x <- seq(-10, 10, length.out = 50)
#
# > y <- x
#
# > rotsinc <- function(x,y)
# + {
# +     sinc <- function(x) { y <- sin(x)/x ; y[is.na(y)] <- 1; y }
# +     10 * sinc( sqrt(x^2+y^2) )
# + }
#
# > sinc.exp <- expression(z == Sinc(sqrt(x^2 + y^2)))
#
# > z <- outer(x, y, rotsinc)
#
# > oldpar <- par(bg = "white")
#
# > persp(x, y, z, theta = 30, phi = 30, expand = 0.5, col = "lightblue")
#
# > title(sub=".")## work around persp+plotmath bug
#
# > title(main = sinc.exp)
#
# > persp(x, y, z, theta = 30, phi = 30, expand = 0.5, col = "lightblue",
# +       ltheta = 120, shade = 0.75, ticktype = "detailed",
# +       xlab = "X", ylab = "Y", zlab = "Z")
# ...

# %% [markdown]
# # Creating Dataset
#
# ## R data structure

# %% [markdown]
# <td> <img src="RDataStructures.png" alt="Drawing" style="width: 900px;"/> </td>

# %% [markdown]
# ### vectors
#
# ```r
# a <- c(1, 2, -4, 9, 5)
# b <- c("one", "two", "three")
# c <- c(TRUE, TRUE, FALSE, TRUE)
# ```

# %% [markdown]
# ```r
# a[3] = -4
# b[c(1,2)] = "one" "two"
# c[2:4] = FALSE TRUE FALSE TRUE
# ```

# %% [markdown]
# ### Matrices
# A matrix is a two-dimensional array.
#
# ```r
# y <- matrix(1:20, nrow=5, ncol=4)
# ```

# %%
y <- matrix(1:20, nrow=5, ncol=4)
y
# Out:
#      [,1] [,2] [,3] [,4]
# [1,] 1     6   11   16
# [2,] 2     7   12   17
# [3,] 3     8   13   18
# [4,] 4     9   14   19
# [5,] 5    10   15   20

# %% [markdown]
# ```r
# cells <- c(1, 26, 24, 68)
# rnames <- c("R1","R2")
# cnames <- c("C1","C2")
# mymatrix <- matrix(cells,nrows=2,ncol=2, byrow=TRUE, dimnames=list(rnames,cnames))
# ```

# %%
y <- matrix(1:20, nrow=5, ncol=4)
cells <- c(1, 26, 24, 68)
rnames <- c("R1","R2")
cnames <- c("C1","C2")
mymatrix <- matrix(cells, nrow= 2, ncol=2, byrow=TRUE, dimnames=list(rnames,cnames))
mymatrix
# Out:
#    C1 C2
# R1  1 26
# R2 24 68

# %%
y <- matrix(1:20, nrow=5, ncol=4)
cells <- c(1, 26, 24, 68)
rnames <- c("R1","R2")
cnames <- c("C1","C2")
mymatrix <- matrix(cells, nrow= 2, ncol=2, byrow=FALSE, dimnames=list(rnames,cnames))
mymatrix
# Out:
#    C1 C2
# R1  1 24
# R2 26 68

# %% [markdown]
# ```r
# x <- matrix(1:10, nrow= 2)
# ```

# %%
x <- matrix(1:10, nrow= 2)
x
# Out:
#      [,1] [,2] [,3] [,4] [,5]
# [1,] 1    3    5    7     9
# [2,] 2    4    6    8    10

# %% [markdown]
# ```r
# x[2,]
# ```

# %%
x[2,]
# Out:
# [1]  2  4  6  8 10

# %% [markdown]
# ```r
# x[1,4]
# ```

# %%
x[1,4]
# Out:
# [1] 7

# %% [markdown]
# ```r
# x[1,c(4,5)]
# ```

# %%
x[1,c(4,5)]
# Out:
# [1] 7 9

# %% [markdown]
# ### Data frames
# A data frame is more general than a matrix, where different columns can contain different modes of data (numeric, character, etc). It is the same as SAS, SPSS and Stata.

# %% [markdown]
# ```r
# mydata <- data.frame(col1, col2, col3,...)
# ```

# %% [markdown]
# ```r
# patientID <- c(1, 2, 3, 4)
# age <- c(25, 34, 28, 52)
# diabetes <- c("Type1","Type2","Type1","Type1")
# status <- c("Poor","Improved","Excellent","Poor")
# patientdata <- data.frame(patientID, age, diabetes, status)
# ```

# %%
patientID <- c(1, 2, 3, 4)
age <- c(25, 34, 28, 52)
diabetes <- c("Type1","Type2","Type1","Type1")
status <- c("Poor","Improved","Excellent","Poor")
patientdata <- data.frame(patientID, age, diabetes, status)
patientdata
# Out:
#   patientID age diabetes status
# 1 1         25  Type1    Poor
# 2 2         34  Type2    Improved
# 3 3         28  Type1    Excellent
# 4 4         52  Type1    Poor

# %% [markdown]
# ```r
# patientdata[1:2]
# patientdata[c("patientID","age")]
# ```

# %%
patientdata[1:2]
patientdata[c("patientID","age")]
# Out:
#   patientID age
# 1 1         25
# 2 2         34
# 3 3         28
# 4 4         52
#   patientID age
# 1 1         25
# 2 2         34
# 3 3         28
# 4 4         52

# %% [markdown]
# ```r
# table(patientdata$diabetes, patientdata$status)
# ```

# %%
table(patientdata$diabetes, patientdata$status)
# Out:
#
#         Excellent Improved Poor
#   Type1         1        0    2
#   Type2         0        1    0

# %% [markdown]
# ```r
# attach()
# detach()
# ```

# %% [markdown]
# ### Lists
# Lists are the most complex of the R data type. It allows you to gather a variety of objects under one name.
# ```r
# mylist<-list(object1, object2, object3, ...)
# ```

# %% [markdown]
# ```r
# g<- "My first list"
# h <- c(25, 26, 18, 39)
# j <- matrix(1:10, nrow=5)
# k <- c("one", "two", "three")
# mylist <- list(title=g, ages= h, j, k)
# mylist
# ```

# %%
g<- "My first list"
h <- c(25, 26, 18, 39)
j <- matrix(1:10, nrow=5)
k <- c("one", "two", "three")
mylist <- list(title=g, ages= h, j, k)
mylist
# Out:
# $title
# [1] "My first list"
#
# $ages
# [1] 25 26 18 39
#
# [[3]]
#      [,1] [,2]
# [1,]    1    6
# [2,]    2    7
# [3,]    3    8
# [4,]    4    9
# [5,]    5   10
#
# [[4]]
# [1] "one"   "two"   "three"

# %%
mylist[[2]]
# Out:
# Error in eval(expr, envir, enclos): object 'mylist' not found
# Traceback:

# %%
mylist[["ages"]]
# Out:
# [1] 25 26 18 39

# %% [markdown]
# ## Data input
# ![sourcesOfDataImportedIntoR.jpg](attachment:sourcesOfDataImportedIntoR.jpg)

# %% [markdown]
# __Import data from text file__
# ```r
# mydataframe<- read.table(file_Location, Options)
# ```

# %% [markdown]
# __Import data from Excel file__
# ```r
# library(xlsx)
# mydataframe<- read.xlsx(file_Location, Options)
# ```

# %% [markdown]
# __Import data from SPSS__
# ```r
# library("Hmisc")
# mydataframe <- spss.get(file_Location, Options)
# ```

# %% [markdown]
# Import data from SAS
# ```r
# library("Hmisc")
# mydataframe <- sas.get(file_Location, Options)
# ```
# ```r
# library("sas7bdat")
# mydataframe <- read.sas7bdat(file_Location, Options)
#
# ```

# %% [markdown]
# ## Extract Data from Web Sites

# %%
####################
#####################
library(rvest)
library(purrr)
page_bookings <- c("https://www.booking.com/searchresults.html?aid=397594&label=gog235jc-1FCAEoggI46AdIM1gDaDuIAQGYAQe4ARfIAQzYAQHoAQH4AQyIAgGoAgO4Atap6PoFwAIB0gIkY2RhYmM2NTUtMDRkNS00ODY1LWE3MDYtNzQ1ZmRmNjY3NWY52AIG4AIB&sid=00a81a799e3af316911ec01de9a0f9fa&sb=1&src=searchresults&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Fsearchresults.html%3Faid%3D397594%3Blabel%3Dgog235jc-1FCAEoggI46AdIM1gDaDuIAQGYAQe4ARfIAQzYAQHoAQH4AQyIAgGoAgO4Atap6PoFwAIB0gIkY2RhYmM2NTUtMDRkNS00ODY1LWE3MDYtNzQ1ZmRmNjY3NWY52AIG4AIB%3Bsid%3D00a81a799e3af316911ec01de9a0f9fa%3Btmpl%3Dsearchresults%3Bac_click_type%3Db%3Bac_position%3D0%3Bclass_interval%3D1%3Bdest_id%3D-3096949%3Bdest_type%3Dcity%3Bdtdisc%3D0%3Bfrom_sf%3D1%3Bgroup_adults%3D2%3Bgroup_children%3D0%3Binac%3D0%3Bindex_postcard%3D0%3Blabel_click%3Dundef%3Bno_rooms%3D1%3Boffset%3D0%3Bpostcard%3D0%3Braw_dest_type%3Dcity%3Broom1%3DA%252CA%3Bsb_price_type%3Dtotal%3Bsearch_selected%3D1%3Bshw_aparth%3D1%3Bslp_r_match%3D0%3Bsrc%3Dsearchresults%3Bsrc_elem%3Dsb%3Bsrpvid%3Db25759b5acc30085%3Bss%3DMakkah%252C%2520Makkah%2520Al%2520Mukarramah%2520Province%252C%2520Saudi%2520Arabia%3Bss_all%3D0%3Bss_raw%3DMakk%3Bssb%3Dempty%3Bsshis%3D0%3Bssne%3DSpain%3Bssne_untouched%3DSpain%3Btop_ufis%3D1%26%3B&ss=Mecca&is_ski_area=0&ssne=Mecca&ssne_untouched=Mecca&city=-3096949&checkin_year=2021&checkin_month=4&checkin_monthday=1&checkout_year=2021&checkout_month=4&checkout_monthday=4&group_adults=2&group_children=0&no_rooms=1&from_sf=1") %>%
  paste0(1:4) %>%
  paste0(c("?ie=UTF8&pageNumber=")) %>%
  paste0(1:4) %>%
  paste0(c("&pageSize=10&sortBy=recent"))

hotelss <-
  map_dfr(
    page_bookings,
    function(url) {
      pg <- read_html(url)
      items <- pg %>%
        html_nodes(".sr_item")
      data.frame(
        hotel = items %>% html_node(xpath = "./descendant::*[contains(@class,'sr-hotel__name')]") %>% html_text(trim = T),
        price = items %>% html_node(xpath = "./descendant::*[contains(@class,'bui-price-display__value')]") %>% html_text(trim = T)
      )
    }
  )
#######################
########################
hotelss
# Out:
#     hotel
# 1   Pullman ZamZam Makkah
# 2   Swissotel Al Maqam Makkah
# 3   Jabal Omar Hyatt Regency Makkah
# 4   Raffles Makkah Palace
# 5   Dar Al Tawhid Intercontinental Makkah, an IHG hotel
# 6   Hilton Suites Makkah
# 7   Makkah Clock Royal Tower, A Fairmont Hotel
# 8   Holiday Suites Al Aziziah
# 9   Le Meridien Makkah
# 10  Al Marwa Rayhaan by Rotana - Makkah
# 11  Conrad Makkah
# 12  Al Ghufran Safwah Hotel Makkah
# 13  Park Inn by Radisson Makkah Aziziyah
# 14  Four Points by Sheraton Makkah Al Naseem
# 15  Swissôtel Makkah
# 16  Mövenpick Hotel & Residence Hajar Tower Makkah
# 17  Park Inn by Radisson Makkah Al Naseem
# 18  Hilton Makkah Convention Hotel
# 19  <U+0641><U+0646><U+062F><U+0642> <U+0628><U+0631><U+0627><U+062F><U+0627><U+064A><U+0633> <U+0627><U+0644><U+0634><U+0634><U+0629>
# 20  Elaf Kinda Hotel
# 21  Shaza Makkah
# 22  Al Safwah Royale Orchid Hotel
# 23  Violet Al Azizia Hotel
# 24  Makkah Hotel
# 25  Violet Al Shisha Hotel
# 26  Pullman ZamZam Makkah
# ...

# %%
#################
#################
#loading the package:>
library(xml2)
library(rvest)
library(stringr)
library(pander)
#Sys.getlocale("LC_ALL")
#localeCategories <- c("LC_COLLATE","LC_CTYPE","LC_MONETARY","LC_NUMERIC","LC_TIME")
#locales <- setNames(sapply(localeCategories, Sys.getlocale), localeCategories)



#l10n_info()[2:3][(l10n_info()[2:3])==TRUE]
#(native <- ifelse(l10n_info()[[2]], "UTF-8", ifelse(l10n_info()[[3]], "latin1", "unknown")))
#(native <- ifelse(l10n_info()[[2]], "UTF-8", ifelse(l10n_info()[[3]], "latin1", "unknown")))
#(foreign <- switch(native, "latin1"="UTF-8", "UTF-8"="latin1", "UTF-8"))
#l10n_info()
#(foreign <- switch(native, "latin1"="UTF-8", "UTF-8"="latin1", "UTF-8"))
Sys.setlocale("LC_ALL","Arabic")
#Specifying the url for desired website to be 
scrappedurl <- "https://www.amazon.sa/%D9%84%D8%A7%D8%B3%D9%84%D9%83%D9%8A%D8%A9-%D8%A7%D9%84%D8%B6%D9%88%D8%B6%D8%A7%D8%A1-%D8%AA%D8%A7%D9%88%D8%AA%D8%B1%D9%88%D9%86%D9%83%D8%B3-%D9%85%D8%A7%D9%8A%D9%83%D8%B1%D9%88%D9%81%D9%88%D9%86-%D8%A7%D9%84%D8%A7%D9%86%D8%AA%D8%B1%D9%86%D8%AA%D8%8C/dp/B082LQDT2C/ref=lp_16966390031_1_6"
#Reading the html content from 
Amazonwebpage<-read_html(scrappedurl)
Amazonwebpage
#scrape title of the product> 
title_html <- html_nodes(Amazonwebpage, 'h1#title')
title <- html_text(title_html)
title
TITLE<-str_replace_all(title, "[\n]" , "")
#TITLE
#head(title)
##title_html <- html_nodes(Amazonwebpage, 'span#productTitle.a-size-large product-title-word-break')
#title <- html_text(title_html)
#head(title)







######################
# remove all space and new lines
# scrape the price of the product> 
#price_html <- html_nodes(Amazonwebpage, 'div#desktop_unifiedPrice.celwidget')
#price_html <- html_nodes(Amazonwebpage, 'div#price')
#price <- html_text(price_html)
#price

#str_replace_all(price, "[\n]" , "")

#str_replace_all(price, "[\r\n\t]" , "")
###############################

# scrape the price of the product> 
#price_html <- html_nodes(Amazonwebpage, 'div#unifiedPrice_feature_div')
#price <- html_text(price_html)
#price

#str_replace_all(price, "[\n]" , "")

# scrape the price of the product> 
price_html <- html_nodes(Amazonwebpage, '#priceblock_ourprice')
price <- html_text(price_html)
#price

PRICE<-str_replace_all(price, "[\n]" , "")
#PRICE

###############################################

##############################

   # vcsAllText <- str_replace_all(price,"\n","")
    #print(vcsAllText)
   # vcsAllText <- trimws(price, which = c("both"))
#vcsAllText
 #scrape product description> 
desc_html <- html_nodes(Amazonwebpage, 'div#productDescription')
desc <- html_text(desc_html)
# replace new lines and spaces> 
desc <- str_replace_all(desc, "[\r\n\t]" , "")
desc <- str_trim(desc)
#(desc)

# scrape product rating > 
rate_html <- html_nodes(Amazonwebpage, 'span#acrPopover')
rate <- html_text(rate_html)
# remove spaces and newlines and tabs > 
rate <- str_replace_all(rate, "[\r\n]" , "")
rate <- str_trim(rate)
#rate[1]
##################
##################
SDSDSD<-data.frame(title= TITLE, price= PRICE, DESC =desc, RATE=rate[1])#, physical_price = str_replace_all(price, "[\n]" , ""))#, kindle_price = kindle_price )



head(SDSDSD)
#pander(SDSDSD)
# Out:
# [1] "LC_COLLATE=Arabic_Saudi Arabia.1256;LC_CTYPE=Arabic_Saudi Arabia.1256;LC_MONETARY=Arabic_Saudi Arabia.1256;LC_NUMERIC=C;LC_TIME=Arabic_Saudi Arabia.1256"
# {html_document}
# <html lang="ar-ae" class="a-no-js" data-19ax5a9jf="dingo" dir="rtl">
# [1] <head>\n<script>var aPageStart = (new Date()).getTime();</script><meta ch ...
# [2] <body class="a-aui_72554-c a-aui_mm_desktop_exp_291916-c a-aui_mm_desktop ...
# [1] "\n\n\n\n\n\n\n\n\nسماعات راس لاسلكية بخاصية الغاء الضوضاء من تاوترونكس [2020]، وقت التشغيل يستغرق 40 ساعة، شاحن سريع من النوع سي، بلوتوث 5.0، سي في سي 8.0، مع مايكروفون للحصص عبر الانترنت، بلون اسود\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#   title
# 1 سماعات راس لاسلكية بخاصية الغاء الضوضاء من تاوترونكس [2020]، وقت التشغيل يستغرق 40 ساعة، شاحن سريع من النوع سي، بلوتوث 5.0، سي في سي 8.0، مع مايكروفون للحصص عبر الانترنت، بلون اسود
#   price
# 1 179.99 ريال
#   DESC
# ...

# %% [markdown]
# ## Other Data input options
# ### `scan` function

# %%
#################
#################
#loading the package:>
library(xml2)
library(rvest)
library(stringr)
#Specifying the url for desired website to be 
scrappedurl <- "https://www.amazon.com/GS65-Stealth-i7-8750H-Notebook-Computer/dp/B07MQ73SPZ/ref=sr_1_4?keywords=2080+laptops+2tb+ssd&qid=1555596596&s=electronics&sr=1-4"
#Reading the html content from 
Amazonwebpage<-read_html(scrappedurl)

page.title <- html_node(Amazonwebpage,'title')
page.title <- html_text(page.title)
print(page.title)
# Out:
# [1] "Amazon.com: CUK GS65 Stealth Ultra Thin Gaming Laptop (Intel Core i9-9880H, NVIDIA GeForce RTX 2080 8GB Max-Q, 32GB RAM, 1TB NVMe SSD, 15.6\" Full HD 240Hz, Windows 10 Pro) Best New Light Gamer Notebook Computer: Electronics"

# %% [markdown]
# # Data management

# %% [markdown]
# <p><span style="font-size: 14pt;">Example 1</span></p>
# <pre><code class="cm-s-ipython language-r"><span class="cm-variable">manager</span> <span class="cm-operator cm-arrow">&lt;-</span> <span class="cm-variable">c</span>(<span class="cm-number">1</span>, <span class="cm-number">2</span>, <span class="cm-number">3</span>, <span class="cm-number">4</span>, <span class="cm-number">5</span>)
# <span class="cm-variable">date</span> <span class="cm-operator cm-arrow">&lt;-</span> <span class="cm-variable">c</span>(<span class="cm-string">"</span><span class="cm-string">10/24/08"</span>, <span class="cm-string">"</span><span class="cm-string">10/28/08"</span>, <span class="cm-string">"</span><span class="cm-string">10/1/08"</span>, <span class="cm-string">"</span><span class="cm-string">10/12/08"</span>, <span class="cm-string">"</span><span class="cm-string">5/1/09"</span>)
# <span class="cm-variable">country</span> <span class="cm-operator cm-arrow">&lt;-</span> <span class="cm-variable">c</span>(<span class="cm-string">"</span><span class="cm-string">US"</span>, <span class="cm-string">"</span><span class="cm-string">US"</span>, <span class="cm-string">"</span><span class="cm-string">UK"</span>, <span class="cm-string">"</span><span class="cm-string">UK"</span>, <span class="cm-string">"</span><span class="cm-string">UK"</span>)
# <span class="cm-variable">gender</span> <span class="cm-operator cm-arrow">&lt;-</span> <span class="cm-variable">c</span>(<span class="cm-string">"</span><span class="cm-string">M"</span>, <span class="cm-string">"</span><span class="cm-string">F"</span>, <span class="cm-string">"</span><span class="cm-string">F"</span>, <span class="cm-string">"</span><span class="cm-string">M"</span>, <span class="cm-string">"</span><span class="cm-string">F"</span>)
# <span class="cm-variable">age</span> <span class="cm-operator cm-arrow">&lt;-</span> <span class="cm-variable">c</span>(<span class="cm-number">32</span>, <span class="cm-number">45</span>, <span class="cm-number">25</span>, <span class="cm-number">39</span>, <span class="cm-number">99</span>)
# <span class="cm-variable">q1</span> <span class="cm-operator cm-arrow">&lt;-</span> <span class="cm-variable">c</span>(<span class="cm-number">5</span>, <span class="cm-number">3</span>, <span class="cm-number">3</span>, <span class="cm-number">3</span>, <span class="cm-number">2</span>)
# <span class="cm-variable">q2</span> <span class="cm-operator cm-arrow">&lt;-</span> <span class="cm-variable">c</span>(<span class="cm-number">4</span>, <span class="cm-number">5</span>, <span class="cm-number">5</span>, <span class="cm-number">3</span>, <span class="cm-number">2</span>)
# <span class="cm-variable">q3</span> <span class="cm-operator cm-arrow">&lt;-</span> <span class="cm-variable">c</span>(<span class="cm-number">5</span>, <span class="cm-number">2</span>, <span class="cm-number">5</span>, <span class="cm-number">4</span>, <span class="cm-number">1</span>)
# <span class="cm-variable">q4</span> <span class="cm-operator cm-arrow">&lt;-</span> <span class="cm-variable">c</span>(<span class="cm-number">5</span>, <span class="cm-number">5</span>, <span class="cm-number">5</span>, <span class="cm-atom">NA</span>, <span class="cm-number">2</span>)
# <span class="cm-variable">q5</span> <span class="cm-operator cm-arrow">&lt;-</span> <span class="cm-variable">c</span>(<span class="cm-number">5</span>, <span class="cm-number">5</span>, <span class="cm-number">2</span>, <span class="cm-atom">NA</span>, <span class="cm-number">1</span>)
# <span class="cm-variable">leadership</span> <span class="cm-operator cm-arrow">&lt;-</span> <span class="cm-variable">data.frame</span>(<span class="cm-variable">manager</span>, <span class="cm-variable">date</span>, <span class="cm-variable">country</span>, <span class="cm-variable">gender</span>, <span class="cm-variable">age</span>,
#                          <span class="cm-variable">q1</span>, <span class="cm-variable">q2</span>, <span class="cm-variable">q3</span>, <span class="cm-variable">q4</span>, <span class="cm-variable">q5</span>, <span class="cm-variable">stringsAsFactors</span><span class="cm-operator">=</span><span class="cm-atom">FALSE</span>)
# <span class="cm-variable">leadership</span></code></pre>

# %%
manager <- c(1, 2, 3, 4, 5)
date <- c("10/24/08", "10/28/08", "10/1/08", "10/12/08", "5/1/09")
country <- c("US", "US", "UK", "UK", "UK")
gender <- c("M", "F", "F", "M", "F")
age <- c(32, 45, 25, 39, 99)
q1 <- c(5, 3, 3, 3, 2)
q2 <- c(4, 5, 5, 3, 2)
q3 <- c(5, 2, 5, 4, 1)
q4 <- c(5, 5, 5, NA, 2)
q5 <- c(5, 5, 2, NA, 1)
leadership <- data.frame(manager, date, country, gender, age,
                         q1, q2, q3, q4, q5, stringsAsFactors=FALSE)
leadership
# Out:
#   manager date     country gender age q1 q2 q3 q4 q5
# 1 1       10/24/08 US      M      32  5  4  5   5  5
# 2 2       10/28/08 US      F      45  3  5  2   5  5
# 3 3       10/1/08  UK      F      25  3  5  5   5  2
# 4 4       10/12/08 UK      M      39  3  3  4  NA NA
# 5 5       5/1/09   UK      F      99  2  2  1   2  1

# %% [markdown]
# ## <p><span style="font-size: 14pt;">Creating new variables</span></p>
#
# <td> <img src="Arithmetic_operations.png" alt="Drawing" style="width: 900px;"/> </td>
#
# ```r
# sumx<- x1+x2
#
# meanx<- (x1+x2)/2
#
# ```

# %%
mydata<-data.frame(x1 = c(2, 2, 6, 4),
                   x2 = c(3, 4, 2, 8))
mydata

mydata$sumx  <-  mydata$x1 + mydata$x2
mydata$meanx <- (mydata$x1 + mydata$x2)/2

attach(mydata)
mydata$sumx  <-  x1 + x2
mydata$meanx <- (x1 + x2)/2
detach(mydata)

mydata <- transform(mydata,
                    sumx  =  x1 + x2,
                    meanx = (x1 + x2)/2)
mydata
# Out:
#   x1 x2
# 1 2  3
# 2 2  4
# 3 6  2
# 4 4  8
#   x1 x2 sumx meanx
# 1 2  3   5   2.5
# 2 2  4   6   3.0
# 3 6  2   8   4.0
# 4 4  8  12   6.0

# %% [markdown]
# ## Recording variables
#
# <div>
# <img src="attachment:Logical_operations.png" width="800"/>
# </div>

# %%
leadership$age[leadership$age == 99] <- NA
leadership$agecat[leadership$age  > 75]    <- "Elder"
leadership$agecat[leadership$age >= 55 &
                  leadership$age <= 75]    <- "Middle Aged"
leadership$agecat[leadership$age  < 55]    <- "Young"
leadership
# Out:
#   manager date     country gender age q1 q2 q3 q4 q5 agecat
# 1 1       10/24/08 US      M      32  5  4  5   5  5 Young
# 2 2       10/28/08 US      F      45  3  5  2   5  5 Young
# 3 3       10/1/08  UK      F      25  3  5  5   5  2 Young
# 4 4       10/12/08 UK      M      39  3  3  4  NA NA Young
# 5 5       5/1/09   UK      F      NA  2  2  1   2  1 NA

# %%
leadership <- within(leadership,{
                     agecat <- NA
                     agecat[age > 75]              <- "Elder"
                     agecat[age >= 55 & age <= 75] <- "Middle Aged"
                     agecat[age < 55]              <- "Young" })
leadership
# Out:
#   manager date     country gender age q1 q2 q3 q4 q5 agecat
# 1 1       10/24/08 US      M      32  5  4  5   5  5 Young
# 2 2       10/28/08 US      F      45  3  5  2   5  5 Young
# 3 3       10/1/08  UK      F      25  3  5  5   5  2 Young
# 4 4       10/12/08 UK      M      39  3  3  4  NA NA Young
# 5 5       5/1/09   UK      F      NA  2  2  1   2  1 NA

# %% [markdown]
# ## Missing variables
#
# ```r
# y <- c(1, 2, 3, NA)
# is.na(y)
# ```

# %%
y <- c(1, 2, 3, NA)
is.na(y)
is.na(leadership[,6:10])
leadership
# Out:
# [1] FALSE FALSE FALSE  TRUE
#      q1    q2    q3    q4    q5
# [1,] FALSE FALSE FALSE FALSE FALSE
# [2,] FALSE FALSE FALSE FALSE FALSE
# [3,] FALSE FALSE FALSE FALSE FALSE
# [4,] FALSE FALSE FALSE  TRUE  TRUE
# [5,] FALSE FALSE FALSE FALSE FALSE
#   manager date     country gender age q1 q2 q3 q4 q5 agecat
# 1 1       10/24/08 US      M      32  5  4  5   5  5 Young
# 2 2       10/28/08 US      F      45  3  5  2   5  5 Young
# 3 3       10/1/08  UK      F      25  3  5  5   5  2 Young
# 4 4       10/12/08 UK      M      39  3  3  4  NA NA Young
# 5 5       5/1/09   UK      F      NA  2  2  1   2  1 NA

# %%
x <- c(1, 2, NA, 3)
y <- x[1] + x[2] + x[3] + x[4]
z <- sum(x)
x <- c(1, 2, NA, 3)
y <- sum(x, na.rm=TRUE)
y
y <- sum(x, na.rm=FALSE)
y
# Out:
# [1] 6
# [1] NA

# %%
newdata<- na.omit(leadership)
newdata
# Out:
#   manager date     country gender age q1 q2 q3 q4 q5 agecat
# 1 1       10/24/08 US      M      32  5  4  5  5  5  Young
# 2 2       10/28/08 US      F      45  3  5  2  5  5  Young
# 3 3       10/1/08  UK      F      25  3  5  5  5  2  Young

# %% [markdown]
# ## Subsetting datasets
# ```r
# newdata<- leadership[,c(6:10)]
# newdata
# ```

# %%
newdata<- leadership[,c(6:10)]
newdata
myvars<- c("q1","q2","q3","q4","q5")
newdata<- leadership[myvars]
newdata
myvars<- paste("q",1:5, sep = "")
myvars
newdata<- leadership[myvars]
newdata
# Out:
#   q1 q2 q3 q4 q5
# 1 5  4  5   5  5
# 2 3  5  2   5  5
# 3 3  5  5   5  2
# 4 3  3  4  NA NA
# 5 2  2  1   2  1
#   q1 q2 q3 q4 q5
# 1 5  4  5   5  5
# 2 3  5  2   5  5
# 3 3  5  5   5  2
# 4 3  3  4  NA NA
# 5 2  2  1   2  1
# [1] "q1" "q2" "q3" "q4" "q5"
#   q1 q2 q3 q4 q5
# 1 5  4  5   5  5
# 2 3  5  2   5  5
# 3 3  5  5   5  2
# 4 3  3  4  NA NA
# 5 2  2  1   2  1

# %% [markdown]
# ### Selecting observations
# ```r
# newdata <- leadership[1:3,]
#
# newdata <- leadership[which(leadership$gender=="M" &
#                             leadership$age > 30),]
#
# attach(leadership)
# newdata <- leadership[which(gender=='M' & age > 30),]
# detach(leadership)
# ```

# %%
newdata <- leadership[1:3,]

newdata <- leadership[which(leadership$gender=="M" &
                            leadership$age > 30),]

attach(leadership)
newdata <- leadership[which(gender=='M' & age > 30),]
detach(leadership)
newdata
# Out:
# The following objects are masked _by_ .GlobalEnv:
#
#     age, country, date, gender, manager, q1, q2, q3, q4, q5
#   manager date     country gender age q1 q2 q3 q4 q5 agecat
# 1 1       10/24/08 US      M      32  5  4  5   5  5 Young
# 4 4       10/12/08 UK      M      39  3  3  4  NA NA Young

# %%
leadership$date <- as.Date(leadership$date, "%m/%d/%y")
startdate <- as.Date("2009-01-01")
enddate   <- as.Date("2009-10-31")
newdata <- leadership[which(leadership$date >= startdate &
leadership$date <= enddate),]
leadership
# Out:
#   manager date       country gender age q1 q2 q3 q4 q5 agecat
# 1 1       2008-10-24 US      M      32  5  4  5   5  5 Young
# 2 2       2008-10-28 US      F      45  3  5  2   5  5 Young
# 3 3       2008-10-01 UK      F      25  3  5  5   5  2 Young
# 4 4       2008-10-12 UK      M      39  3  3  4  NA NA Young
# 5 5       2009-05-01 UK      F      NA  2  2  1   2  1 NA

# %%
head(iris)
dim(iris)
#iris$Species
#iris
boxplot(Sepal.Length~(Species),data=iris)
library("reshape2")
reshaped.iris<-melt(iris,id=("Species"))
dim(reshaped.iris)
reshaped.iris
library(lattice)
bwplot(value ~ Species | variable, data=reshaped.iris)
bwplot(value ~ variable | Species, data=reshaped.iris)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa
# [1] 150   5
# Warning message:
# "package 'reshape2' was built under R version 4.0.3"
# [1] 600   3
#     Species   variable     value
# 1   setosa    Sepal.Length 5.1
# 2   setosa    Sepal.Length 4.9
# 3   setosa    Sepal.Length 4.7
# 4   setosa    Sepal.Length 4.6
# 5   setosa    Sepal.Length 5.0
# 6   setosa    Sepal.Length 5.4
# 7   setosa    Sepal.Length 4.6
# 8   setosa    Sepal.Length 5.0
# 9   setosa    Sepal.Length 4.4
# 10  setosa    Sepal.Length 4.9
# 11  setosa    Sepal.Length 5.4
# 12  setosa    Sepal.Length 4.8
# 13  setosa    Sepal.Length 4.8
# ...

# %% [markdown]
# ## data management challenge
#
# <td> <img src="mathematical functions.png" alt="Drawing" style="width: 900px;"/> </td>

# %% [markdown]
# <td> <img src="statistical functions.png" alt="Drawing" style="width: 900px;"/> </td>

# %% [markdown]
# ### Applying function to matrices
#
# ```r
# # Listing 5.5 - Applying a function to the rows
# # (columns) of a matrix
#
# mydata <- matrix(rnorm(30), nrow=6)
# mydata
# ```

# %%
mydata <- matrix(rnorm(30), nrow=6)
mydata
apply(mydata, 1, mean)     
apply(mydata, 2, mean)
# Out:
#      [,1]       [,2]         [,3]        [,4]       [,5]
# [1,]  0.2050276 -0.719458017  1.26424328 -0.9606198 -0.8429170
# [2,]  1.3610982  0.006129277  0.32207925  0.6203396  1.2945588
# [3,] -0.3705546  0.770877857 -0.61557082 -1.1510548  1.1045191
# [4,] -0.7295330 -0.125947877 -1.84606333 -1.3426693  0.2033064
# [5,] -0.3400704  0.851589726 -0.02270912 -1.1911118  0.4682422
# [6,]  0.4444430  0.736475120  1.57556435  1.0008536  0.4014469
# [1] -0.21074481  0.72084101 -0.05235667 -0.76818144 -0.04681188  0.83175659
# [1]  0.09506844  0.25327768  0.11292394 -0.50404377  0.43819273

# %%
options(digits=2)

Student <- c("John Davis", "Angela Williams", 
    "Bullwinkle Moose", "David Jones", 
    "Janice Markhammer", "Cheryl Cushing",
    "Reuven Ytzrhak", "Greg Knox", "Joel England",
    "Mary Rayburn")
Math <- c(502, 600, 412, 358, 495, 512, 410, 625, 573, 522)
Science <- c(95, 99, 80, 82, 75, 85, 80, 95, 89, 86)
English <- c(25, 22, 18, 15, 20, 28, 15, 30, 27, 18)
roster <- data.frame(Student, Math, Science, English,
    stringsAsFactors=FALSE)
roster
z <- scale(roster[,2:4]) 
z
score <- apply(z, 1, mean)                                            
roster <- cbind(roster, score)
roster
y <- quantile(score, c(.8,.6,.4,.2))   

roster$grade[score >= y[1]] <- "A"                                     
roster$grade[score < y[1] & score >= y[2]] <- "B"
roster$grade[score < y[2] & score >= y[3]] <- "C"
roster$grade[score < y[3] & score >= y[4]] <- "D"
roster$grade[score < y[4]] <- "F"

name <- strsplit((roster$Student), " ")                                
lastname <- sapply(name, "[", 2)
firstname <- sapply(name, "[", 1)

roster <- cbind(firstname,lastname, roster[,-1])
roster <- roster[order(lastname,firstname),]
roster
# Out:
#    Student           Math Science English
# 1  John Davis        502  95      25
# 2  Angela Williams   600  99      22
# 3  Bullwinkle Moose  412  80      18
# 4  David Jones       358  82      15
# 5  Janice Markhammer 495  75      20
# 6  Cheryl Cushing    512  85      28
# 7  Reuven Ytzrhak    410  80      15
# 8  Greg Knox         625  95      30
# 9  Joel England      573  89      27
# 10 Mary Rayburn      522  86      18
#       Math   Science English
#  [1,]  0.013  1.078   0.587
#  [2,]  1.143  1.591   0.037
#  [3,] -1.026 -0.847  -0.697
#  [4,] -1.649 -0.590  -1.247
#  [5,] -0.068 -1.489  -0.330
#  [6,]  0.128 -0.205   1.137
#  [7,] -1.049 -0.847  -1.247
#  [8,]  1.432  1.078   1.504
#  [9,]  0.832  0.308   0.954
# [10,]  0.243 -0.077  -0.697
#    Student           Math Science English score
# 1  John Davis        502  95      25       0.56
# 2  Angela Williams   600  99      22       0.92
# 3  Bullwinkle Moose  412  80      18      -0.86
# ...

# %%
Stu.Grade = read.csv("https://raw.githubusercontent.com/mlforsachid/MSDSQ1/master/Data607/Week6/StudentGrades.csv", stringsAsFactors = F)
Stu.Grade
# Out:
#   name  math science history
# 1 James 68   56      80
# 2 Bob   90   50      67
# 3 Amit  45   89      90

# %%
grades<-read.table(studentgrades.csv,header = TRUE)
# Out:
# Error in read.table(studentgrades.csv, header = TRUE): object 'studentgrades.csv' not found
# Traceback:
#
# 1. read.table(studentgrades.csv, header = TRUE)

# %% [markdown]
# <pre><code data-line-numbers="3-5|8-10|13-15">
# <table>
#   <tr>
#     <td>Apples</td>
#     <td>$1</td>
#     <td>7</td>
#   </tr>
#   <tr>
#     <td>Oranges</td>
#     <td>$2</td>
#     <td>18</td>
#   </tr>
#   <tr>
#     <td>Kiwi</td>
#     <td>$3</td>
#     <td>1</td>
#   </tr>
# </table>
# </code></pre>

# %% [markdown]
# #  R Graphics

# %% [markdown]
# ## How to explore your data quickly
# ```r
# attach(mtcars)
# plot(wt, mpg)
# abline(lm(mpg~wt))
# title("Regression of MPG on Weight")
# detach(mtcars)
# ```

# %%
dose  <- c(20, 30, 40, 45, 60)
drugA <- c(16, 20, 27, 40, 60)
drugB <- c(15, 18, 25, 31, 40)
plot(dose, drugA, type="b")
plot(dose)
# Out:
# plot without title
# plot without title

# %% [markdown]
# ## Simple bar plot
# - Bar plot displays the frequency distribution of categorical variables

# %%
# Load vcd package
library(vcd)

# Get cell counts for improved variable
counts <- table(Arthritis$Improved)
counts
# Out:
# Loading required package: grid
#   None   Some Marked
#     42     14     28

# %%
# simple bar plot
barplot(counts, main = "Simple Bar Plot", xlab = "Improvement", 
    ylab = "Frequency")

# horizontal bar plot
barplot(counts, main = "Horizontal Bar Plot", xlab = "Frequency", 
    ylab = "Improvement", horiz = TRUE)


# get counts for Improved by Treatment table
counts <- table(Arthritis$Improved, Arthritis$Treatment)
counts
# Out:
# Plot with title "Simple Bar Plot"
#
#          Placebo Treated
#   None        29      13
#   Some         7       7
#   Marked       7      21
# Plot with title "Horizontal Bar Plot"

# %% [markdown]
# ## Stacked and groupde bar plots

# %%
# stacked barplot
barplot(counts, main = "Stacked Bar Plot", xlab = "Treatment", 
    ylab = "Frequency", col = c("red", "yellow", "green"), 
    legend = rownames(counts))

# grouped barplot
barplot(counts, main = "Grouped Bar Plot", xlab = "Treatment", 
    ylab = "Frequency", col = c("red", "yellow", "green"), 
    legend = rownames(counts), 
    beside = TRUE)
# Out:
# Plot with title "Stacked Bar Plot"
# Plot with title "Grouped Bar Plot"

# %% [markdown]
# ## Mean bar plots

# %%
states <- data.frame(state.region, state.x77)
means <- aggregate(states$Illiteracy, 
    by = list(state.region), 
    FUN = mean)
means

means <- means[order(means$x), ]
means

barplot(means$x, names.arg = means$Group.1)
title("Mean Illiteracy Rate")
# Out:
#   Group.1       x
# 1 Northeast     1.000000
# 2 South         1.737500
# 3 North Central 0.700000
# 4 West          1.023077
#   Group.1       x
# 3 North Central 0.700000
# 1 Northeast     1.000000
# 4 West          1.023077
# 2 South         1.737500
# Plot with title "Mean Illiteracy Rate"

# %%
par(mar = c(5, 8, 4, 2))
par(las = 2)
counts <- table(Arthritis$Improved)
barplot(counts, main = "Treatment Outcome", horiz = TRUE, 
    cex.names = 0.8, names.arg = c("No Improvement", 
    "Some Improvement", "Marked Improvement"))
# Out:
#   None   Some Marked
#     42     14     28
# Plot with title "Treatment Outcome"

# %% [markdown]
# ### Spinograms

# %%
library(vcd)
attach(Arthritis)
counts <- table(Treatment, Improved)
spine(counts, main = "Spinogram Example")
detach(Arthritis)
# Out:
# plot without title

# %% [markdown]
# <h2 id="4.2&nbsp;&nbsp;R-graphical-parameters" data-toc-modified-id="4.2&nbsp;&nbsp;R-graphical-parameters-4.2"><a id="4.2&nbsp;&nbsp;R-graphical-parameters-4.2" class="toc-mod-link"></a><span class="toc-item-num">4.2&nbsp;&nbsp;</span>R graphical parameters</h2>
# <p>One can customize many features of your graphs (<strong>fonts</strong>, <strong>colors</strong>, <strong>axes</strong>, <strong>titles</strong>) through graphic options.</p>
# <p>&nbsp;</p>
# <p><img src="data:image/png;base64,..." alt="" width="738" height="316" /></p>

# %% [markdown]
# <p><img src="data:image/png;base64,..." alt="" width="670" height="213" /></p>

# %% [markdown]
# <p><img src="data:image/png;base64,..." alt="" width="843" height="260" /></p>

# %%
plot(dose, drugA, type="b", lty = 6, lwd = 3, pch=15)
# Out:
# plot without title

# %%
attach(mtcars)
#mtcars
#plot(mtcars$wt, mtcars$mpg)
#plot(wt, mpg)
#abline(lm(mpg~wt))
#title("Regression of MPG on Weight")
#detach(mtcars)
plot(pressure$temperature, pressure$pressure, type = "l")
points(pressure$temperature, pressure$pressure)

lines(pressure$temperature, pressure$pressure/2, col = "red")
points(pressure$temperature, pressure$pressure/2, col = "red")
# Out:
# The following objects are masked from mtcars (pos = 3):
#
#     am, carb, cyl, disp, drat, gear, hp, mpg, qsec, vs, wt
#
#
# The following objects are masked from mtcars (pos = 4):
#
#     am, carb, cyl, disp, drat, gear, hp, mpg, qsec, vs, wt
#
#
# The following objects are masked from mtcars (pos = 5):
#
#     am, carb, cyl, disp, drat, gear, hp, mpg, qsec, vs, wt
#
#
# The following objects are masked from mtcars (pos = 6):
#
#     am, carb, cyl, disp, drat, gear, hp, mpg, qsec, vs, wt
#
#
# The following objects are masked from mtcars (pos = 7):
#
#     am, carb, cyl, disp, drat, gear, hp, mpg, qsec, vs, wt
#
#
# The following objects are masked from mtcars (pos = 8):
#
#     am, carb, cyl, disp, drat, gear, hp, mpg, qsec, vs, wt
#
#
# The following objects are masked from mtcars (pos = 9):
#
#     am, carb, cyl, disp, drat, gear, hp, mpg, qsec, vs, wt
#
#
# The following objects are masked from mtcars (pos = 10):
#
#     am, carb, cyl, disp, drat, gear, hp, mpg, qsec, vs, wt
#
# ...

# %%
BOD
barplot(BOD$demand, names.arg = BOD$Time)
barplot(table(mtcars$cyl))
# Out:
#   Time demand
# 1 1     8.3
# 2 2    10.3
# 3 3    19.0
# 4 4    16.0
# 5 5    15.6
# 6 7    19.8
# plot without title
# plot without title

# %% [markdown]
# <section>
# 	<a href="#/grand-finale">Go to the last slide</a>
# </section>
# <section>
# 	<h2>Slide 2</h2>
# </section>
# <section id="grand-finale">
# 	<h2>The end</h2>
# 	<a href="#/0">Back to the first</a>
# </section>

# %% [markdown]
# <p class="fragment" data-fragment-index="3">Appears last</p>
# <p class="fragment" data-fragment-index="1">Appears first</p>
# <p class="fragment" data-fragment-index="2">Appears second</p>

# %% [markdown]
# # Regression
# ## Simple linear regression
# It is the simplest form of regression

# %%
library(UsingR)
require(ggplot2)
require(reshape2)
head(father.son)
ggplot(father.son,aes(x=fheight, y=sheight))+ 
 geom_point()+
geom_smooth(method = "lm")+ labs(x="Fathers",y="Sons")

heightsLM <- lm(sheight~fheight, data=father.son)
heightsLM
summary(heightsLM)
# Out:
#   fheight  sheight
# 1 65.04851 59.77827
# 2 63.25094 63.21404
# 3 64.95532 63.34242
# 4 65.75250 62.79238
# 5 61.13723 64.28113
# 6 63.02254 64.24221
# `geom_smooth()` using formula 'y ~ x'
# Call:
# lm(formula = sheight ~ fheight, data = father.son)
#
# Coefficients:
# (Intercept)      fheight
#     33.8866       0.5141
# Call:
# lm(formula = sheight ~ fheight, data = father.son)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -8.8772 -1.5144 -0.0079  1.6285  8.9685
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 33.88660    1.83235   18.49   <2e-16 ***
# fheight      0.51409    0.02705   19.01   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.437 on 1076 degrees of freedom
# Multiple R-squared:  0.2513,	Adjusted R-squared:  0.2506
# F-statistic: 361.2 on 1 and 1076 DF,  p-value: < 2.2e-16
# plot without title

# %%
t.test(father.son$fheight,father.son$sheight,paired = TRUE)
heightDiff<-father.son$fheight-father.son$sheight
ggplot(father.son,aes(x=fheight-sheight))+
    geom_density() +
    geom_vline(xintercept = mean(heightDiff)) +
    geom_vline(xintercept = mean(heightDiff) +
        2*c(-1,1)*sd(heightDiff)/sqrt(nrow(father.son)),
    linetype=2)
tipAnova<-aov(tip~day-1,tips)
#tipIntercept <- aov(tip~day,tips)

# %% [markdown]
# ## Multiple Regression
# It is the logical extension to simple regression, which allows for multiple predictors.

# %%
housing<- read.table("http://www.jaredlander.com/data/housing.csv", sep = ",",
                    header =TRUE,
                    stringsAsFactors = FALSE)
head(housing)
names(housing)
# Out:
#   Neighborhood Building.Classification Total.Units Year.Built Gross.SqFt
# 1 FINANCIAL    R9-CONDOMINIUM           42         1920        36500
# 2 FINANCIAL    R4-CONDOMINIUM           78         1985       126420
# 3 FINANCIAL    RR-CONDOMINIUM          500           NA       554174
# 4 FINANCIAL    R4-CONDOMINIUM          282         1930       249076
# 5 TRIBECA      R4-CONDOMINIUM          239         1985       219495
# 6 TRIBECA      R4-CONDOMINIUM          133         1986       139719
#   Estimated.Gross.Income Gross.Income.per.SqFt Estimated.Expense
# 1  1332615               36.51                  342005
# 2  6633257               52.47                 1762295
# 3 17310000               31.24                 3543000
# 4 11776313               47.28                 2784670
# 5 10004582               45.58                 2783197
# 6  5127687               36.70                 1497788
#   Expense.per.SqFt Net.Operating.Income Full.Market.Value Market.Value.per.SqFt
# ...

# %%
names(housing)<- c("Neighborhood","Class","Units","YearBuilt","SqFt",
                 "Income","IncomeperSqFt","Expense","ExpenseperSqFt","NetIncome",
                  "Value","ValueperSqFt","Boro")
head(housing)
# Out:
#   Neighborhood Class          Units YearBuilt SqFt   Income   IncomeperSqFt
# 1 FINANCIAL    R9-CONDOMINIUM  42   1920       36500  1332615 36.51
# 2 FINANCIAL    R4-CONDOMINIUM  78   1985      126420  6633257 52.47
# 3 FINANCIAL    RR-CONDOMINIUM 500     NA      554174 17310000 31.24
# 4 FINANCIAL    R4-CONDOMINIUM 282   1930      249076 11776313 47.28
# 5 TRIBECA      R4-CONDOMINIUM 239   1985      219495 10004582 45.58
# 6 TRIBECA      R4-CONDOMINIUM 133   1986      139719  5127687 36.70
#   Expense ExpenseperSqFt NetIncome Value    ValueperSqFt Boro
# 1  342005  9.37            990610   7300000 200.00       Manhattan
# 2 1762295 13.94           4870962  30690000 242.76       Manhattan
# 3 3543000  6.39          13767000  90970000 164.15       Manhattan
# 4 2784670 11.18           8991643  67556006 271.23       Manhattan
# 5 2783197 12.68           7221385  54320996 247.48       Manhattan
# 6 1497788 10.72           3629899  26737996 191.37       Manhattan

# %%
ggplot(housing,aes(x=ValueperSqFt)) +
    geom_histogram(binwidth = 10) + labs(x="Value per Square Foot")
# Out:
# plot without title

# %%
ggplot(housing,aes(x=ValueperSqFt,fill=Boro)) +
    geom_histogram(binwidth = 10) + labs(x="Value per Square Foot")
# Out:
# plot without title

# %%
ggplot(housing,aes(x=ValueperSqFt,fill=Boro)) +
    geom_histogram(binwidth = 10) + labs(x="Value per Square Foot")+
facet_wrap(~Boro)
# Out:
# plot without title

# %%
ggplot(housing,aes(x=SqFt)) + geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(housing,aes(x=Units)) + geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(housing[housing$Units <1000,], aes(x=SqFt)) +geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(housing[housing$Units <1000,], aes(x=Units)) +geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(housing, aes(x=SqFt, y=ValueperSqFt))+geom_point()
# Out:
# plot without title

# %%
ggplot(housing, aes(x=Units, y=ValueperSqFt))+geom_point()
# Out:
# plot without title

# %%
ggplot(housing[housing$Units <1000,], aes(x=SqFt, y=ValueperSqFt)) +geom_point()
# Out:
# plot without title

# %%
ggplot(housing[housing$Units <1000,], aes(x=Units, y=ValueperSqFt)) +geom_point()
# Out:
# plot without title

# %%
# How many need to be removed?
sum(housing$Units >=1000)
# Out:
# [1] 6

# %%
# remove them
housing <- housing[housing$Units <1000,]

# %%
# plot ValuePerSqFt against SqFt
ggplot(housing, aes(x=SqFt, y=ValueperSqFt)) + geom_point()
# Out:
# plot without title

# %%
ggplot(housing, aes(x=log(SqFt), y=ValueperSqFt)) + geom_point()
# Out:
# plot without title

# %%
ggplot(housing, aes(x=SqFt, y=log(ValueperSqFt))) + geom_point()
# Out:
# plot without title

# %%
ggplot(housing, aes(x=log(SqFt), y=log(ValueperSqFt))) + geom_point()
# Out:
# plot without title

# %%
# plot ValuePerSqFt against Units
ggplot(housing, aes(x=Units, y=ValueperSqFt)) + geom_point()
# Out:
# plot without title

# %%
ggplot(housing, aes(x=log(Units), y=ValueperSqFt)) + geom_point()
# Out:
# plot without title

# %%
ggplot(housing, aes(x=Units, y=log(ValueperSqFt))) + geom_point()
# Out:
# plot without title

# %%
ggplot(housing, aes(x=log(Units), y=log(ValueperSqFt))) + geom_point()
# Out:
# plot without title

# %%
house1 <- lm(ValueperSqFt ~ Units + SqFt + Boro, data =housing)
summary(house1)
# Out:
# Call:
# lm(formula = ValueperSqFt ~ Units + SqFt + Boro, data = housing)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -168.458  -22.680    1.493   26.290  261.761
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)        4.430e+01  5.342e+00   8.293  < 2e-16 ***
# Units             -1.532e-01  2.421e-02  -6.330 2.88e-10 ***
# SqFt               2.070e-04  2.129e-05   9.723  < 2e-16 ***
# BoroBrooklyn       3.258e+01  5.561e+00   5.858 5.28e-09 ***
# BoroManhattan      1.274e+02  5.459e+00  23.343  < 2e-16 ***
# BoroQueens         3.011e+01  5.711e+00   5.272 1.46e-07 ***
# BoroStaten Island -7.114e+00  1.001e+01  -0.711    0.477
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 43.2 on 2613 degrees of freedom
# Multiple R-squared:  0.6034,	Adjusted R-squared:  0.6025
# F-statistic: 662.6 on 6 and 2613 DF,  p-value: < 2.2e-16

# %%
house1$coefficients
# Out:
#       (Intercept)             Units              SqFt      BoroBrooklyn
#      4.430325e+01     -1.532405e-01      2.069727e-04      3.257554e+01
#     BoroManhattan        BoroQueens BoroStaten Island
#      1.274259e+02      3.011000e+01     -7.113688e+00

# %%
coef(house1)
# Out:
#       (Intercept)             Units              SqFt      BoroBrooklyn
#      4.430325e+01     -1.532405e-01      2.069727e-04      3.257554e+01
#     BoroManhattan        BoroQueens BoroStaten Island
#      1.274259e+02      3.011000e+01     -7.113688e+00

# %%
coefficients(house1)
# Out:
#       (Intercept)             Units              SqFt      BoroBrooklyn
#      4.430325e+01     -1.532405e-01      2.069727e-04      3.257554e+01
#     BoroManhattan        BoroQueens BoroStaten Island
#      1.274259e+02      3.011000e+01     -7.113688e+00

# %%
require(coefplot)
coefplot(house1)
# Out:
# Loading required package: coefplot
# plot without title

# %%
house2<- lm(ValueperSqFt~ Units * SqFt +Boro,data=housing)
house3<- lm(ValueperSqFt~ Units:SqFt +Boro,data=housing)
house2$coefficients
# Out:
#       (Intercept)             Units              SqFt      BoroBrooklyn
#      4.093685e+01     -1.024579e-01      2.362293e-04      3.394544e+01
#     BoroManhattan        BoroQueens BoroStaten Island        Units:SqFt
#      1.272102e+02      3.040115e+01     -8.419682e+00     -1.809587e-07

# %%
house3$coefficients
# Out:
#       (Intercept)      BoroBrooklyn     BoroManhattan        BoroQueens
#      4.804972e+01      3.141208e+01      1.302084e+02      2.841669e+01
# BoroStaten Island        Units:SqFt
#     -7.199902e+00      1.088059e-07

# %%
coefplot(house2)
coefplot(house3)
# Out:
# plot without title
# plot without title

# %%
house4<- lm(ValueperSqFt~ SqFt * Units * Income,data=housing)
house4$coefficients
# Out:
#       (Intercept)              SqFt             Units            Income
#      1.116433e+02     -1.694688e-03      7.142611e-03      7.250830e-05
#        SqFt:Units       SqFt:Income      Units:Income SqFt:Units:Income
#      3.158094e-06     -5.129522e-11     -1.279236e-07      9.107312e-14

# %%
house5<-lm(ValueperSqFt~ Class * Boro,data=housing)
house5$coefficients
# Out:
#                           (Intercept)                   ClassR4-CONDOMINIUM
#                             47.041481                              4.023852
#                   ClassR9-CONDOMINIUM                   ClassRR-CONDOMINIUM
#                             -2.838624                              3.688519
#                          BoroBrooklyn                         BoroManhattan
#                             27.627141                             89.598397
#                            BoroQueens                     BoroStaten Island
#                             19.144780                             -9.203410
#      ClassR4-CONDOMINIUM:BoroBrooklyn      ClassR9-CONDOMINIUM:BoroBrooklyn
#                              4.117977                              2.660419
#      ClassRR-CONDOMINIUM:BoroBrooklyn     ClassR4-CONDOMINIUM:BoroManhattan
#                            -25.607141                             47.198900
# ...

# %%
house6<-lm(ValueperSqFt~ I(SqFt/Units) +Boro,data=housing)
house6$coefficients
# Out:
#       (Intercept)     I(SqFt/Units)      BoroBrooklyn     BoroManhattan
#      43.754838763       0.004017039      30.774343209     130.769502685
#        BoroQueens BoroStaten Island
#      29.767922792      -6.134446417

# %%
# Also from the coefplot package
multiplot(house1, house2, house3)
# Out:
# plot without title

# %% [markdown]
# # Conclusions and Next Steps
# Summarize findings here
